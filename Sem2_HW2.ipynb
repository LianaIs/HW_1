# %% [markdown]
# ## Problem 1
# You know that each BankAccount object has attributes id, balance and rate. Use builder pattern and any extra classes and methods that you may need to realize the creation of a BankAccount type object. Create some objects and do some operations to test your classes.

# %%
from __future__ import annotations
from abc import ABC, abstractmethod, abstractproperty
from typing import Any


class Builder(ABC):
    
    @abstractmethod
    def create_i_d(self, _id):
        pass

    @abstractmethod
    def create_balance(self, _balance):
        pass
    
    @abstractmethod
    def create_rate(self, _rate):
        pass

    
    def create_socialID(self, _socialID):
        pass
    
    def create_HVHH(self, _hvhh):
        pass
    


class Business(Builder):


    def __init__(self):
        self.BankAccount = BankAccount()

    def create_i_d(self, _id):
        self.BankAccount.add(_id)

    def create_balance(self, _balance):
        self.BankAccount.add(_balance)
        
    def create_rate(self, _rate):
        self.BankAccount.add(_rate)
        
    def create_socialID(self, _socialID):
        self.BankAccount.add(_socialID)
        

class Individual(Builder):


    def __init__(self):
        self.BankAccount = BankAccount()

    def create_i_d(self, _id):
        self.BankAccount.add(_id)

    def create_balance(self, _balance):
        self.BankAccount.add(_balance)
        
    def create_rate(self, _rate):
        self.BankAccount.add(_rate)

    def create_HVHH(self, _hvhh):
        self.BankAccount.add(_hvhh)



class BankAccount():

    def __init__(self):
        self.decription = []

    def add(self, desc: int):
        self.decription.append(desc)

    def describe(self):
        print(f"Account code {', '.join(self.decription)}", end="")



builder = Business()

print("Custom account1: ")

builder.create_i_d('0001')
builder.create_balance('1000000')
builder.BankAccount.describe()
              
builder = Individual()

print("\nCustom account2: ")

builder.create_i_d('0002')
builder.create_balance('2000000')
builder.create_HVHH('0123456')
builder.BankAccount.describe()
# Out:
# Custom account1:
# Account code 0001, 1000000
# Custom account2:
# Account code 0002, 2000000, 0123456

# %% [markdown]
# ## Problem 2
# Use prototype design pattern and classes of your choice. create an abstract class Shape and concrete classes extending the Shape class: Circle, Square and Rectangle. Define a class ShapeCache which stores shape objects in a dictionary and returns their clones when requested. Create some objects and do some operations to test your classes.

# %%
from abc import ABCMeta, abstractmethod
import copy
  
  

class Shapes(metaclass = ABCMeta):
      
    def __init__(self):
        self.id = None
        self.type = None
  
    @abstractmethod
    def shape(self):
        pass
  
    def get_type(self):
        return self.type
  
    def perpendicular(self):
        return self.id
  
    def width(self, sid):
        self.id = sid
  
    def clone(self):
        return copy.copy(self)
  

class Art_course(Courses_At_AUA):
    def __init__(self, name):
        super().__init__()
        time.sleep(5)
        self.name = name
        self.type = "Art category course"
  
    def course(self):
        print("Inside ART::course() method")
  
class Technical_course(Courses_At_AUA):
    def __init__(self, name):
        super().__init__()
        time.sleep(5)
        self.name = name
        self.type = "Technical category course"
  
    def course(self):
        print("Inside TECHNICAL::course() method")
  
class Language_course(Courses_At_AUA):
    def __init__(self, name):
        super().__init__()
        time.sleep(5)
        self.name = name
        self.type = "Language category course"
  
    def course(self):
        print("Inside LANGUAGE::course() method")
  
# cache class
class Courses_At_AUA_Cache:
      
    
    cache = {}
  
    @staticmethod
    def get_course(cid):
        SHAPE = Shapes_Cache.cache.get(cid, None)
        return COURSE.clone() 
  
    @staticmethod
    def load():
        art = Art_course('art intro')
        art.set_id("1")
        Courses_At_AUA_Cache.cache[art.get_id()] = art
  
        tech = Technical_course('math')
        tech.set_id("2")
        Courses_At_AUA_Cache.cache[tech.get_id()] = tech
  
        lang = Language_course('eng')
        lang.set_id("3")
        Courses_At_AUA_Cache.cache[lang.get_id()] = lang
  
# main function
#if __name__ == '__main__':
Courses_At_AUA_Cache.load()

square = Shapes_Cache.get_course("1")
print(art.get_type())

triangle = Shapes_Cache.get_course("2")
print(tech.get_type())

circle = Shapes_Cache.get_course("3")
print(lang.get_type())
